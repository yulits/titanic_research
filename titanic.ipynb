# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.hist(figsize=(15,10))
plt.show()

# %%
train.plot(kind='density', subplots=True, layout=(3,3), figsize=(15, 10), sharex=False)
plt.show()

# %%
train = train_1.copy()
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(12, 10))
plt.show()

# %% [markdown]
# ### Correlation Matrix Plot

# %%
corr_names = ['PasId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
correlations = train.corr()
# plot correlation matrix
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0, len(corr_names), 1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(corr_names)
ax.set_yticklabels(corr_names)
plt.show()

# %%
correlations.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
correlations
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
categorical_columns = [c for c in train.columns if train[c].dtype.name == 'object']
numerical_columns   = [c for c in train.columns if train[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Betros, Mr. Tannous  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare        Cabin  \
# ...

# %%
train.describe(include=['object', 'bool'])
# Out:
#                        Name   Sex  Ticket        Cabin Embarked
# count                   891   891     891          204      889
# unique                  891     2     681          147        3
# top     Betros, Mr. Tannous  male  347082  C23 C25 C27        S
# freq                      1   577       7            4      644

# %%
# Scatter matrix
scatter_matrix?

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.05, figsize=(13, 13), grid=True)
plt.show()

# %%
numarical_columns = [x for x in train.columns if train[x].dtype.name != 'object']
sns.pairplot(train[numarical_columns].dropna())

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
sns_plot.savefig('pairplot.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1052a5f977e6> in <module>()
# ----> 1 sns_plot.savefig('pairplot.png')
#
# NameError: name 'sns_plot' is not defined

# %%
sns.distplot(train['Fare']);  #distribution

# %%
sns.jointplot(train['Age'], train['Fare']);

# %%
train[numerical_columns]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0              1         0       3  22.0      1      0    7.2500
# 1              2         1       1  38.0      1      0   71.2833
# 2              3         1       3  26.0      0      0    7.9250
# 3              4         1       1  35.0      1      0   53.1000
# 4              5         0       3  35.0      0      0    8.0500
# 5              6         0       3   NaN      0      0    8.4583
# 6              7         0       1  54.0      0      0   51.8625
# 7              8         0       3   2.0      3      1   21.0750
# 8              9         1       3  27.0      0      2   11.1333
# 9             10         1       2  14.0      1      0   30.0708
# 10            11         1       3   4.0      1      1   16.7000
# 11            12         1       1  58.0      0      0   26.5500
# 12            13         0       3  20.0      0      0    8.0500
# ...

# %%
numerical_columns = [x for x in train.columns if train[x].dtype.name != 'object']
df = train[numerical_columns]
sns.heatmap(df.corr());

# %%
df = df.drop('Survived')
# Out:
# (2, 0)

# %% [markdown]
# ### как признаки связаны с целевым

# %%
numerical_columns = [x for x in df.columns if df[x].dtype.name != 'object']

# %%
#df = train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df['Sex'] = df['Sex'].apply(lambda x: 0 if x=='male' else 1)

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(16, 10))

for idx, feat in  enumerate(numerical_columns):
    
    sns.boxplot(x='Survived', y=feat, data=df, ax=axes[idx // 3, idx % 3])
    axes[idx // 3, idx % 3].legend()
    axes[idx // 3, idx % 3].set_xlabel('Survived')
    axes[idx // 3, idx % 3].set_ylabel(feat);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
sns.countplot(x='Pclass', hue='Survived', data=df);

# %%
train.groupby(['Embarked'])['Survived'].agg([np.mean]).sort_values(by='mean', ascending=False)
# Out:
#               mean
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
train.groupby(['Embarked']).size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train[train['Age'] == train['Age'].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
train[train['Name'].str.contains('Mary')]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 32            33         1       3
# 318          319         1       1
# 322          323         1       2
# 347          348         1       3
# 358          359         1       3
# 359          360         1       3
# 381          382         1       3
# 383          384         1       1
# 472          473         1       2
# 501          502         0       3
# 502          503         0       3
# 518          519         1       2
# 573          574         1       3
# 593          594         0       3
# 635          636         1       2
# 767          768         0       3
# 772          773         0       2
# 853          854         1       1
# 856          857         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ...

# %%
train.groupby(['Embarked', 'Sex']).size()
# Out:
# Embarked  Sex
# C         female     73
#           male       95
# Q         female     36
#           male       41
# S         female    203
#           male      441
# dtype: int64

# %%
train.groupby(['Embarked', 'Sex']).size().index
# Out:
# MultiIndex(levels=[['C', 'Q', 'S'], ['female', 'male']],
#            labels=[[0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1]],
#            names=['Embarked', 'Sex'])

# %%
train.groupby(['Embarked', 'Sex']).size().unstack()
# Out:
# Sex       female  male
# Embarked
# C             73    95
# Q             36    41
# S            203   441

# %%
train['First_name'] = train['Name'].apply(lambda x: x.split()[2].strip('.())'))

# %%
gr = train.groupby(['First_name', 'Embarked']).size().unstack().fillna(0)

# %%
gr.head()
# Out:
# Embarked      C    Q    S
# First_name
# Abraham     0.0  0.0  1.0
# Achille     0.0  0.0  1.0
# Ada         0.0  0.0  1.0
# Adele       1.0  0.0  0.0
# Adola       0.0  0.0  1.0

# %%
indexer = gr.sum(1).argsort()

# %%
indexer.head()
# Out:
# First_name
# Abraham      0
# Achille    269
# Ada        268
# Adele      267
# Adola      266
# dtype: int64

# %%
gr.take(indexer)[-10:]
# Out:
# Embarked      C    Q     S
# First_name
# Mr          2.0  0.0  10.0
# Edward      1.0  0.0  12.0
# Frederick   0.0  0.0  13.0
# Henry       3.0  1.0  11.0
# George      2.0  1.0  12.0
# James       3.0  4.0   8.0
# Charles     2.0  1.0  13.0
# Thomas      2.0  6.0  11.0
# John        6.0  4.0  21.0
# William     3.0  2.0  43.0

# %%
gr.take(indexer)[-10:].plot(kind='barh', stacked=True, figsize=(10, 6))
plt.show()

# %%
popular_names = train.groupby('First_name').size().sort_values(ascending=False)[:10]
popular_names
# Out:
# First_name
# William      48
# John         31
# Thomas       19
# George       16
# Charles      16
# James        15
# Henry        15
# Edward       13
# Frederick    13
# Mr           12
# dtype: int64

# %%
gr.loc[popular_names.index]
# Out:
# Embarked      C    Q     S
# First_name
# William     3.0  2.0  43.0
# John        6.0  4.0  21.0
# Thomas      2.0  6.0  11.0
# George      2.0  1.0  12.0
# Charles     2.0  1.0  13.0
# James       3.0  4.0   8.0
# Henry       3.0  1.0  11.0
# Edward      1.0  0.0  12.0
# Frederick   0.0  0.0  13.0
# Mr          2.0  0.0  10.0

# %%
train.groupby(['Embarked', 'Sex'])['Survived'].sum()
# Out:
# Embarked  Sex
# C         female     64
#           male       29
# Q         female     27
#           male        3
# S         female    140
#           male       77
# Name: Survived, dtype: int64

# %%
train.shape
# Out:
# (891, 12)

# %%
train[train.Age.notnull()].shape
# Out:
# (714, 12)

# %%
train[train.Cabin.notnull()].shape
# Out:
# (204, 12)

# %%
train.dropna().shape
# Out:
# (183, 12)

# %%
train['Mary'] = np.where(train['Name'].str.contains('Mary'), 'Mary', 'Not Mary')
train['Mary'].head()
# Out:
# 0    Not Mary
# 1    Not Mary
# 2    Not Mary
# 3    Not Mary
# 4    Not Mary
# Name: Mary, dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Mary           891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.drop('Mary', axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.pivot_table('Survived', index='Sex', columns='Pclass', aggfunc='mean')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
age = pd.cut(train['Age'], [0, 18, 80])

# %%
train.pivot_table('Survived', index=['Sex', age], columns='Pclass')
# Out:
# Pclass                  1         2         3
# Sex    Age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
fare = pd.qcut(train['Fare'], 2)

# %%
train.pivot_table('Survived', index =['Sex', age], columns=[fare, 'Pclass'])
# Out:
# Fare            (-0.001, 14.454]                     (14.454, 512.329]  \
# Pclass                         1         2         3                 1
# Sex    Age
# female (0, 18]               NaN  1.000000  0.714286          0.909091
#        (18, 80]              NaN  0.880000  0.444444          0.972973
# male   (0, 18]               NaN  0.000000  0.260870          0.800000
#        (18, 80]              0.0  0.098039  0.125000          0.391304
#
# Fare
# Pclass                  2         3
# Sex    Age
# female (0, 18]   1.000000  0.318182
#        (18, 80]  0.914286  0.391304
# male   (0, 18]   0.818182  0.178571
#        (18, 80]  0.030303  0.192308

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
train = train_1.copy()
train = train.drop(['Name', 'First_name', 'Ticket', 'Cabin'], axis=1).dropna()

# %%
y = train['Survived']
X = train.drop(['Survived'], axis=1)
X['Sex'] = X['Sex'].apply(lambda x: 0 if x=='male' else 1)
X.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    0  22.0      1      0   7.2500        S
# 1            2       1    1  38.0      1      0  71.2833        C
# 2            3       3    1  26.0      0      0   7.9250        S
# 3            4       1    1  35.0      1      0  53.1000        S
# 4            5       3    0  35.0      0      0   8.0500        S

# %%
dic = {'S': 1, 'C': 2, 'Q': 3}
X['Embarked'] = X['Embarked'].map(dic)
X
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0              1       3    0  22.0      1      0    7.2500         1
# 1              2       1    1  38.0      1      0   71.2833         2
# 2              3       3    1  26.0      0      0    7.9250         1
# 3              4       1    1  35.0      1      0   53.1000         1
# 4              5       3    0  35.0      0      0    8.0500         1
# 6              7       1    0  54.0      0      0   51.8625         1
# 7              8       3    0   2.0      3      1   21.0750         1
# 8              9       3    1  27.0      0      2   11.1333         1
# 9             10       2    1  14.0      1      0   30.0708         2
# 10            11       3    1   4.0      1      1   16.7000         1
# 11            12       1    1  58.0      0      0   26.5500         1
# 12            13       3    0  20.0      0      0    8.0500         1
# ...

# %%
feat = SelectKBest(score_func=chi2, k=8).fit(X, y)
X_new = feat.transform(X)

# %%
np.set_printoptions(precision=3)

# %%
feat.scores_
# Out:
# array([  9.246e+01,   2.824e+01,   1.305e+02,   3.425e+01,   2.887e-01,
#          1.088e+01,   4.082e+03,   1.806e+00])

# %%
X.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
['%f' % x for x in feat.scores_]
# Out:
# ['0.288691',
#  '1.805830',
#  '10.883500',
#  '28.243213',
#  '34.246098',
#  '92.460193',
#  '130.515207',
#  '4081.679420']

# %%
X = X.drop('Embarked', axis=1)

# %%
Одномерный отбор признаков

# %%
feat = SelectKBest(score_func=chi2, k=4).fit(X, y)
X_new = feat.transform(X)

# %%
['%f' % x for x in feat.scores_]
# Out:
# ['92.460193',
#  '28.243213',
#  '130.515207',
#  '34.246098',
#  '0.288691',
#  '10.883500',
#  '4081.679420']

# %%
X_new
# Out:
# array([[   1.   ,    0.   ,   22.   ,    7.25 ],
#        [   2.   ,    1.   ,   38.   ,   71.283],
#        [   3.   ,    1.   ,   26.   ,    7.925],
#        ...,
#        [ 888.   ,    1.   ,   19.   ,   30.   ],
#        [ 890.   ,    0.   ,   26.   ,   30.   ],
#        [ 891.   ,    0.   ,   32.   ,    7.75 ]])

# %%
X.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare
# 0            1       3    0  22.0      1      0   7.2500
# 1            2       1    1  38.0      1      0  71.2833
# 2            3       3    1  26.0      0      0   7.9250
# 3            4       1    1  35.0      1      0  53.1000
# 4            5       3    0  35.0      0      0   8.0500

# %%
Рекурсивное исключение признаков

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

rfe = RFE(model, 3)

fit = rfe.fit(X, y)

# print("Num Features: %d") % fit.n_features_

# print("Selected Features: %s") % fit.support_

# print("Feature Ranking: %s") % fit.ranking_

# %%
fit.n_features_
# Out:
# 3

# %%
fit.support_
# Out:
# array([False,  True,  True,  True,  True, False, False], dtype=bool)

# %%
fit.ranking_
# Out:
# array([5, 1, 1, 2, 1, 3, 4])

# %%
Метод главных компонент

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=4)

fit = pca.fit(X)

features = fit.transform(X)

# %%
Отбор на основе важности признаков

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()

model.fit(X, y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
model.feature_importances_
# Out:
# array([ 0.165,  0.112,  0.258,  0.191,  0.043,  0.034,  0.197])
